# %%
import pandas as pd
coins = pd.read_csv('DMCoins.csv')

# %%
coins
# Out:
#              Denom  Year  Mintage   Mint_State    Value
# 0         HalfCent  1793    35334        AGood   2500.0
# 1         HalfCent  1793    35334         Good   3500.0
# 2         HalfCent  1793    35334        VGood   5000.0
# 3         HalfCent  1793    35334         Fine   8000.0
# 4         HalfCent  1793    35334        VFine  11000.0
# ...            ...   ...      ...          ...      ...
# 10092  DoubleEagle  1929  1779750  MintState63  35000.0
# 10093  DoubleEagle  1931  2938250  MintState60  32500.0
# 10094  DoubleEagle  1931  2938250  MintState63  60000.0
# 10095  DoubleEagle  1932  1101750  MintState60  50000.0
# 10096  DoubleEagle  1932  1101750  MintState63  70000.0
#
# [10097 rows x 5 columns]

# %%
coinsMS63 = coins[coins['Mint_State'] == 'MintState63']

# %%
coinsMS63
# Out:
#              Denom  Year  Mintage   Mint_State    Value
# 97        HalfCent  1809  1154572  MintState63   1350.0
# 105       HalfCent  1810   215000  MintState63   3200.0
# 113       HalfCent  1811    63140  MintState63  75000.0
# 121       HalfCent  1825    63000  MintState63   1800.0
# 129       HalfCent  1826   234000  MintState63   1000.0
# ...            ...   ...      ...          ...      ...
# 10085  DoubleEagle  1927  2946750  MintState63   2200.0
# 10090  DoubleEagle  1928  8816000  MintState63   2200.0
# 10092  DoubleEagle  1929  1779750  MintState63  35000.0
# 10094  DoubleEagle  1931  2938250  MintState63  60000.0
# 10096  DoubleEagle  1932  1101750  MintState63  70000.0
#
# [1395 rows x 5 columns]

# %%
coinsMS63.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1395 entries, 97 to 10096
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Denom       1395 non-null   object
#  1   Year        1395 non-null   int64
#  2   Mintage     1395 non-null   int64
#  3   Mint_State  1395 non-null   object
#  4   Value       1395 non-null   float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 65.4+ KB

# %%
import seaborn as sns

sns.lmplot(x = 'Year', y = 'Value', data=coinsMS63, hue='Denom', fit_reg=False)

# %%
coinsMS63 = coinsMS63.drop(8659)

# %%
coinsMS63[coinsMS63['Value'] > 1000000]
# Out:
# Empty DataFrame
# Columns: [Denom, Year, Mintage, Mint_State, Value]
# Index: []

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x = 'Year', y = 'Value', data=coinsMS63, hue='Denom', legend=False)
plt.yscale('log')

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(x = 'Year', y = 'Value', data=coins, hue='Denom', legend=False)
plt.yscale('log')
